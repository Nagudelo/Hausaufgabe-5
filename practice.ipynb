# %%
from scipy.interpolate import interp1d
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !head monthrg.dat
# Out:
#  1610  1  0   -99.0   -99.0
#  1610  2  1      .0      .0
#  1610  3  0   -99.0   -99.0
#  1610  4  0   -99.0   -99.0
#  1610  5  0   -99.0   -99.0
#  1610  6  0   -99.0   -99.0
#  1610  7  0   -99.0   -99.0
#  1610  8  0   -99.0   -99.0
#  1610  9  0   -99.0   -99.0
#  1610 10  0   -99.0   -99.0

# %%
data = genfromtxt('monthrg.dat')

# %%
data.shape
# Out:
# (4632, 5)

# %%
data[:,1]
# Out:
# array([  1.,   2.,   3., ...,  10.,  11.,  12.])

# %%
data[:,0]
# Out:
# array([ 1610.,  1610.,  1610., ...,  1995.,  1995.,  1995.])

# %%
1995-1610
# Out:
# 385

# %%
385*12
# Out:
# 4620

# %%
x = linspace(1, 4632, 4632)

# %%
x
# Out:
# array([  1.00000000e+00,   2.00000000e+00,   3.00000000e+00, ...,
#          4.63000000e+03,   4.63100000e+03,   4.63200000e+03])

# %%
scatter(x,data[:,2])

# %%
data[:,2]
# Out:
# array([  0.,   1.,   0., ...,  31.,  30.,  31.])
