# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'fft', 'interp']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
# !head sparse_sample_monthrg.dat
# Out:
# 1610 3 0 -99.0
# 1610 6 0 -99.0
# 1611 9 0 -99.0
# 1612 10 31 100.1
# 1612 11 30 134.4
# 1612 12 25 129.6
# 1613 1 28 118.4
# 1614 11 0 -99.0
# 1615 2 0 -99.0
# 1615 5 0 -99.0

# %%
data = genfromtxt('sparse_sample_monthrg.dat')

# %%
data;

# %%
data[:,2];

# %%
size(data[:,1])
# Out:
# 498

# %%
1995-1610
# Out:
# 385

# %%
385*12
# Out:
# 4620

# %%
x=arange(0,498)
meses=[]
datos=[]
data[3,1]
# Out:
# 10.0

# %%
for i in x:
    if data[i,3]!= -99:
        posicion=(((data[i,0]-data[0,0])*12)+data[i,1])
        meses.append(posicion)
        datos.append(data[i,3])

# %%
meses;
tamano=size(meses)

# %%
scatter(meses, datos)
from scipy.interpolate import interp1d

# %%
interp = interp1d(meses, datos,kind=0)
interp1 = interp1d(meses, datos,kind=1)
interp3 = interp1d(meses, datos,kind=3)

# %%
n=linspace(34,4625,100000)
size(n)
# Out:
# 100000

# %%
scatter(meses, datos)
plot(n,interp(n))

# %%
scatter(meses, datos)
plot(n,interp1(n))

# %%
scatter(meses, datos)
plot(n,interp3(n))

# %%
plot(n,interp(n))
plot(n,interp1(n))
plot(n,interp3(n))

# %%
from scipy.fftpack import fft, fftfreq

# %%
dt = 1 / (f * 32 ) #32 samples per frequency
fourier=fft(interp(meses))
normal=fourier/tamano
fourier1=fft(interp1(meses))
normal1=fourier1/tamano
fourier3=fft(interp3(meses))
normal3=fourier3/tamano
frequ = fftfreq(tamano, dt) # Recuperamos las frecuencias
interp

# %%
plt.plot(frequ,np.abs(normal))
plt.plot(frequ,np.abs(normal1))
plt.plot(frequ,np.abs(normal3))

# %%
potencias=[]
q=arange(0,size(fourier))
for k in q:
    potencias.append(power(abs(fourier[k]),2))
plt.plot(frequ,np.abs(potencias))
